# %%
import numpy as np
import pickle
import gym
import time
import simpleaudio as sa
from threading import Thread
import retro
# from discretizer import Discretizer

# %% [markdown]
# ###### Hyperparams

# %%
H = 200 # number of hidden layer neurons
BATCH_SIZE = 10 # every how many episodes to do a param update?
LEARNING_RATE = 1e-4
GAMMA = 0.99 # discount factor for reward
DECAY_RATE = 0.99 # decay factor for RMSProp leaky sum of grad^2
RESUME = False # RESUME from previous checkpoint?
RENDER = False
PLAY_SOUND = False
RUNS = 3000
MODEL_PICKLE_PATH = 'pong_sound_model.pkl'
REWARED_PICKLE_PATH = 'pong_sound_rewards.pkl'
EPISODE_CIEL = 201 # 8000

# %% [markdown]
# ###### Functions and classes

# %%
def sigmoid(x):
    return 1.0 / (1.0 + np.exp(-x)) # sigmoid "squashing" function to interval [0,1]

def prepro(I, pitch=0):
    """ prepro 210x160x3 uint8 frame into 6400 (80x80) 1D float vector """
    I = I[35:195] # crop
    I = I[::2,::2,0] # downsample by factor of 2
    I[I == 144] = 0 # erase background (background type 1)
    I[I == 109] = 0 # erase background (background type 2)
    I[I != 0] = 1 # everything else (paddles, ball) just set to 1
    i = np.zeros((6401))
    i[:-1] = I.astype(np.float).ravel()
    i[-1] = pitch
    return i

def discount_rewards(r):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0
    for t in reversed(range(0, r.size)):
        if r[t] != 0: running_add = 0 # reset the sum, since this was a game boundary (pong specific!)
        running_add = running_add * GAMMA + r[t]
        discounted_r[t] = running_add
    return discounted_r

def policy_forward(x):
    h = np.dot(model['W1'], x)
    h[h<0] = 0 # ReLU nonlinearity
    logp = np.dot(model['W2'], h)
    p = sigmoid(logp)
    return p, h # return probability of taking action 2, and hidden state

def policy_backward(eph, epdlogp):
    """ backward pass. (eph is array of intermediate hidden states) """
    dW2 = np.dot(eph.T, epdlogp).ravel()
    dh = np.outer(epdlogp, model['W2'])
    dh[eph <= 0] = 0 # backpro prelu
    dW1 = np.dot(dh.T, epx)
    return {'W1':dW1, 'W2':dW2}

class Discretizer(gym.ActionWrapper):
    """
    Wrap a gym environment and make it use discrete actions.
    based on https://github.com/openai/retro-baselines/blob/master/agents/sonic_util.py
    Args:
        combos: ordered list of lists of valid button combinations
    """

    def __init__(self, env, combos):
        super().__init__(env)
        assert isinstance(env.action_space, gym.spaces.MultiBinary)
        buttons = env.unwrapped.buttons
        self._decode_discrete_action = []
        for combo in combos:
            arr = np.array([False] * env.action_space.n)
            for button in combo:
                arr[buttons.index(button)] = True
            self._decode_discrete_action.append(arr)

        self.action_space = gym.spaces.Discrete(len(self._decode_discrete_action))

    def action(self, act):
        return self._decode_discrete_action[act].copy()

# %% [markdown]
# ###### Init model

# %%
# audio = []
check_pitch = False
pitch = 0
reward_sums = []
D = (80 * 80) + 1 # input dimensionality: 80x80 grid
if RESUME:
    model = pickle.load(open(MODEL_PICKLE_PATH, 'rb'))
    reward_sums = pickle.load(open(REWARED_PICKLE_PATH, 'rb'))
else:
    model = {}
    model['W1'] = np.random.randn(H,D) / np.sqrt(D) # "Xavier" initialization
    model['W2'] = np.random.randn(H) / np.sqrt(H)

grad_buffer = { k : np.zeros_like(v) for k,v in model.items() } # update buffers that add up gradients over a batch
rmsprop_cache = { k : np.zeros_like(v) for k,v in model.items() } # rmsprop memory

# env = retro.make(game='Pong-Atari2600', use_restricted_actions=retro.Actions.DISCRETE)
env = retro.make(game='Pong-Atari2600')
d = Discretizer(env, [['UP'], ['DOWN']])
# d = Discretizer(env, [['RIGHT'], ['LEFT']])
# env = Pong_Discretizer(env)
observation = env.reset()
prev_x = None # used in computing the difference frame
xs,hs,dlogps,drs = [],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 0

# %% [markdown]
# ###### Train

# %%
try:
    while episode_number < EPISODE_CIEL:
        if RENDER:
            _ = env.render()

        # preprocess the observation, set input to network to be difference image
        cur_x = prepro(observation, pitch)
        x = cur_x - prev_x if prev_x is not None else np.zeros(D)
        prev_x = cur_x

        # forward the policy network and sample an action from the returned probability
        aprob, h = policy_forward(x)

        #       action = 2 if np.random.uniform() < aprob else 3 # roll the dice!
        #       OLD: 2 = RIGHT = UP, 3 = LEFT = DOWN ; NEW: 0 = UP, 1 = UP
        action = 0 if np.random.uniform() < aprob else 1 # roll the dice!

        # record various intermediates (needed later for backprop)
        xs.append(x) # observation
        hs.append(h) # hidden state

        #      y = 1 if action == 2 else 0 # a "fake label"
        y = 1 if action == 0 else 0 # a "fake label"

        dlogps.append(y - aprob) # grad that encourages the action that was taken to be taken (see http://cs231n.github.io/neural-networks-2/#losses if confused)

        # step the environment and get new measurements
        #       observation, reward, done, info = env.step(env.action_space.sample())

        observation, reward, done, info = env.step(np.array(d.action(action), dtype=np.int8))

        mono = env.em.get_audio()[:,0]
        pitch = 0
        if check_pitch:
            check_pitch = False
            for i in range(len(mono) - 1):
                if (mono[i] == 0) and (mono[i+1] != 0):
                    for j in range(i+1, len(mono)):
                        if mono[j] == 0:
                            break
                        pitch += 1
                    break
        if mono.any():
            check_pitch = True
        #       audio.append(pitch)

        reward_sum += reward

        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: # an episode finished
            episode_number += 1

            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            eph = np.vstack(hs)
            epdlogp = np.vstack(dlogps)
            epr = np.vstack(drs)
            xs,hs,dlogps,drs = [],[],[],[] # reset array memory

            # compute the discounted reward backwards through time
            discounted_epr = discount_rewards(epr)
            # standardize the rewards to be unit normal (helps control the gradient estimator variance)
            discounted_epr -= np.mean(discounted_epr)
            discounted_epr /= np.std(discounted_epr)

            epdlogp *= discounted_epr # modulate the gradient with advantage (PG magic happens right here.)
            grad = policy_backward(eph, epdlogp)
            for k in model: grad_buffer[k] += grad[k] # accumulate grad over batch

            # perform rmsprop parameter update every BATCH_SIZE episodes
            if episode_number % BATCH_SIZE == 0:
                for k,v in model.items():
                    g = grad_buffer[k] # gradient
                    rmsprop_cache[k] = DECAY_RATE * rmsprop_cache[k] + (1 - DECAY_RATE) * g**2
                    model[k] += LEARNING_RATE * g / (np.sqrt(rmsprop_cache[k]) + 1e-5)
                    grad_buffer[k] = np.zeros_like(v) # reset batch gradient buffer

            # boring book-keeping
            running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
            print('resetting env. episode reward total was %f. running mean: %f' % (reward_sum, running_reward))
            reward_sums.append(reward_sum)
            if episode_number % 100 == 0:
                pickle.dump(model, open(MODEL_PICKLE_PATH, 'wb'))
                pickle.dump(reward_sums, open(REWARED_PICKLE_PATH, 'wb'))
            reward_sum = 0
            observation = env.reset() # reset env
            prev_x = None

        if reward != 0: # Pong has either +1 or -1 reward exactly when game ends.
            if reward == -1:
                print ('ep {0}: game finished, reward: {1}'.format(episode_number, reward))
            else:
                print ('ep {0}: game finished, reward: {1} !!!!!!!!'.format(episode_number, reward))
finally:
    env.close()
# Out:
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# ep 0: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# ep 1: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# ep 2: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# ep 3: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# ep 4: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -21.000000
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: 1.0 !!!!!!!!
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# ep 5: game finished, reward: -1.0
# resetting env. episode reward total was -20.000000. running mean: -20.990000
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: 1.0 !!!!!!!!
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# ep 6: game finished, reward: -1.0
# resetting env. episode reward total was -20.000000. running mean: -20.980100
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# ep 7: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.980299
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# ep 8: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.980496
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# ep 9: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.980691
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# ep 10: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.980884
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# ep 11: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.981075
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# ep 12: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.981265
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# ep 13: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.981452
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: 1.0 !!!!!!!!
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# ep 14: game finished, reward: -1.0
# resetting env. episode reward total was -20.000000. running mean: -20.971637
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: -1.0
# ep 15: game finished, reward: 1.0 !!!!!!!!
# ep 15: game finished, reward: -1.0
# resetting env. episode reward total was -20.000000. running mean: -20.961921
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# ep 16: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.962302
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# ep 17: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.962679
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# ep 18: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.963052
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# ep 19: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.963421
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: 1.0 !!!!!!!!
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# ep 20: game finished, reward: -1.0
# resetting env. episode reward total was -20.000000. running mean: -20.953787
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# ep 21: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.954249
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# ep 22: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.954707
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# ep 23: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.955160
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# ep 24: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.955608
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# ep 25: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.956052
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: 1.0 !!!!!!!!
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: 1.0 !!!!!!!!
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# ep 26: game finished, reward: -1.0
# resetting env. episode reward total was -19.000000. running mean: -20.936492
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# ep 27: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.937127
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# ep 28: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.937755
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# ep 29: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.938378
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# ep 30: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.938994
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# ep 31: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.939604
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# ep 32: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.940208
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# ep 33: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.940806
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# ep 34: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.941398
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# ep 35: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.941984
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: 1.0 !!!!!!!!
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# ep 36: game finished, reward: -1.0
# resetting env. episode reward total was -20.000000. running mean: -20.932564
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: -1.0
# ep 37: game finished, reward: 1.0 !!!!!!!!
# ep 37: game finished, reward: -1.0
# resetting env. episode reward total was -20.000000. running mean: -20.923239
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# ep 38: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.924006
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# ep 39: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.924766
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# ep 40: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.925518
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# ep 41: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.926263
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# ep 42: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.927001
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# ep 43: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.927731
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# ep 44: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.928453
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# ep 45: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.929169
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# ep 46: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.929877
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: 1.0 !!!!!!!!
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: 1.0 !!!!!!!!
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# ep 47: game finished, reward: -1.0
# resetting env. episode reward total was -19.000000. running mean: -20.910578
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# ep 48: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.911473
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# ep 49: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.912358
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# ep 50: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.913234
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# ep 51: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.914102
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# ep 52: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.914961
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# ep 53: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.915811
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# ep 54: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.916653
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# ep 55: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.917487
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# ep 56: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.918312
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# ep 57: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.919129
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ep 58: game finished, reward: -1.0
# ...
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# ep 182: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.689583
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# ep 183: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.692687
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: 1.0 !!!!!!!!
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: 1.0 !!!!!!!!
# ep 184: game finished, reward: -1.0
# ep 184: game finished, reward: -1.0
# resetting env. episode reward total was -19.000000. running mean: -20.675760
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# ep 185: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.679003
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# ep 186: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.682212
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# ep 187: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.685390
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: 1.0 !!!!!!!!
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: 1.0 !!!!!!!!
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: 1.0 !!!!!!!!
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# ep 188: game finished, reward: -1.0
# resetting env. episode reward total was -18.000000. running mean: -20.658536
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# ep 189: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.661951
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: 1.0 !!!!!!!!
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# ep 190: game finished, reward: -1.0
# resetting env. episode reward total was -20.000000. running mean: -20.655332
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: 1.0 !!!!!!!!
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: 1.0 !!!!!!!!
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# ep 191: game finished, reward: -1.0
# resetting env. episode reward total was -19.000000. running mean: -20.638778
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# ep 192: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.642390
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# ep 193: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.645967
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# ep 194: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.649507
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# ep 195: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.653012
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# ep 196: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.656482
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# ep 197: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.659917
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# ep 198: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.663318
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# ep 199: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.666685
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# ep 200: game finished, reward: -1.0
# resetting env. episode reward total was -21.000000. running mean: -20.670018
# ep 201: game finished, reward: -1.0

# %% [markdown]
# ###### Junk

# %%
# Insert pitch as new pixel column before preprocessing and flattening
# This will be cut off as preprocessing crops the screen
i = np.zeros((211, 160, 3))
i[:-1,:,:] = observation
i[210] = 3
# Insert pitch as single entry at the end of the flattened preprocessed vector
i = np.zeros((6401))
i[:-1] = I.astype(np.float).ravel()
i[-1] = 3

# %%
class Pong_Discretizer(Discretizer):
    """
    Use Pong discrete actions
    """
    def __init__(self, env):
        super().__init__(env=env, combos=[[None], ['BUTTON'], ['RIGHT'], ['LEFT'], ['SELECT'], ['RESET']])
#         ['BUTTON', None, 'SELECT', 'RESET', 'UP', 'DOWN', 'LEFT', 'RIGHT']

# %%
# d = Discretizer(env, [[None], ['BUTTON'], ['RIGHT'], ['LEFT'], ['SELECT'], ['RESET']])
# d = Discretizer(env, [['BUTTON'], [None], ['SELECT'], ['RESET'], ['UP'], ['DOWN'], ['LEFT'], ['RIGHT']])
d = Discretizer(env, [[None], ['UP'], ['RIGHT'], ['DOWN'], ['LEFT'], ['BUTTON']])

# %%
d.action(5)
# Out:
# array([False, False, False,  True, False, False, False, False])

# %%
from gym pong env: ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']
from retro env: ['BUTTON', None, 'SELECT', 'RESET', 'UP', 'DOWN', 'LEFT', 'RIGHT']

# %% [markdown]
# Discrete 5  - NOOP[0], UP[1], RIGHT[2], DOWN[3], LEFT[4]

# %%
# env = retro.make(game='Pong-Atari2600', use_restricted_actions=retro.Actions.DISCRETE)
env = retro.make(game='Pong-Atari2600', use_restricted_actions=retro.Actions.DISCRETE)
print('retro.Actions.DISCRETE action_space', env.action_space)
env.close()
# Out:
# retro.Actions.DISCRETE action_space Discrete(18)

# %%
env.unwrapped.buttons
